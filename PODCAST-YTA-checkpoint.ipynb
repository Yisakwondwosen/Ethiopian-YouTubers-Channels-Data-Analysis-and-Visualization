# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key='AIzaSyCPGt5qB3YtYUKGF7CvMnR-_QQENaD6Zw8'
channel_id='UCzKNuQ80qNSpt2x-7dsazJg'
youtube=build('youtube' , 'v3' , developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_id):
    request = youtube.channel().list(
        part='snippet,contentDetails,statistics',
        id=channel_id
    )
    response = request.execute()
    return response

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

api_key = 'AIzaSyCPGt5qB3YtYUKGF7CvMnR-_QQENaD6Zw8'
channel_ids = [
    'UCzKNuQ80qNSpt2x-7dsazJg', #MERI_PODCAST
    'UCb3euYUGSY7REtF8NDsMLsA', #Dawit Dreams
    'UCJD-UtyBgYWqvmp_lknn7Lg', #ወቸው GOOD
    'UCVmDiaSJvb6VH3zPmjVkzfw', #Vintage Media
    'UCCBEcsxu4_i5jdzl4A6xg1w', #Gulicha Podcast
    'UCfiYL9vDNUbq4-zlerxOayw' #Bunna ቡና
]
youtube = build('youtube', 'v3', developerKey=api_key)

def get_channel_stats(youtube, channel_id):
    request = youtube.channels().list(
        part='snippet,contentDetails,statistics',
        id=channel_id
    )
    response = request.execute()
    for item in response.get('items', []):
        data = {
            'Channel_name': item['snippet']['title'],
            'Subscribers': item['statistics']['subscriberCount'],
            'Views': item['statistics']['viewCount'],
            'Total_videos': item['statistics']['videoCount'],
            'Playlist_id': item['contentDetails']['relatedPlaylists']['uploads']
        }
        return data

# Call the function for each channel ID
all_channel_stats = []
for channel_id in channel_ids:
    channel_stats = get_channel_stats(youtube, channel_id)
    all_channel_stats.append(channel_stats)

# %%
df = pd.DataFrame(all_channel_stats)

# %%
df
# Out:
#                 Channel_name Subscribers     Views Total_videos  \
# 0               MERI PODCAST       80100   6645187          161
# 1               Dawit Dreams      491000  52141718          860
# 2                  ወቸው GOOD       101000   8664147           52
# 3              Vintage Media        7030    291614           60
# 4  Gulicha Podcast ጉልቻ ፖድካስት       49100   3102527           66
# 5                   Bunna ቡና       44400   1756418           62
#
#                 Playlist_id
# 0  UUzKNuQ80qNSpt2x-7dsazJg
# 1  UUb3euYUGSY7REtF8NDsMLsA
# 2  UUJD-UtyBgYWqvmp_lknn7Lg
# 3  UUVmDiaSJvb6VH3zPmjVkzfw
# 4  UUCBEcsxu4_i5jdzl4A6xg1w
# 5  UUfiYL9vDNUbq4-zlerxOayw

# %%
df['Subscribers']=pd.to_numeric(df['Subscribers'])
df['Views']=pd.to_numeric(df['Views'])
df['Total_videos']=pd.to_numeric(df['Total_videos'])

# %%
df.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# Playlist_id     object
# dtype: object

# %%
sns.set(rc={'figure.figsize':(15,9)})
ax=sns.barplot(x='Channel_name',y='Subscribers',data=df)
# Out:
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4808 (\N{ETHIOPIC SYLLABLE WA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4728 (\N{ETHIOPIC SYLLABLE CA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4813 (\N{ETHIOPIC SYLLABLE WE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4873 (\N{ETHIOPIC SYLLABLE GU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4621 (\N{ETHIOPIC SYLLABLE LE}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
sns.set(rc={'figure.figsize':(15,9)})
ax=sns.barplot(x='Channel_name',y='Views',data=df)
# Out:
# C:\Users\User\anaconda3\envs\YTA-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4808 (\N{ETHIOPIC SYLLABLE WA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4728 (\N{ETHIOPIC SYLLABLE CA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4813 (\N{ETHIOPIC SYLLABLE WE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4873 (\N{ETHIOPIC SYLLABLE GU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4621 (\N{ETHIOPIC SYLLABLE LE}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
sns.set(rc={'figure.figsize':(15,9)})
ax=sns.barplot(x='Channel_name',y='Total_videos',data=df)
# Out:
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4808 (\N{ETHIOPIC SYLLABLE WA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4728 (\N{ETHIOPIC SYLLABLE CA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4813 (\N{ETHIOPIC SYLLABLE WE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4873 (\N{ETHIOPIC SYLLABLE GU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4621 (\N{ETHIOPIC SYLLABLE LE}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
sns.set(rc={'figure.figsize':(15,9)})
ax=sns.barplot(x='Channel_name',y='Playlist_id',data=df)
# Out:
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4808 (\N{ETHIOPIC SYLLABLE WA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4728 (\N{ETHIOPIC SYLLABLE CA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4813 (\N{ETHIOPIC SYLLABLE WE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4873 (\N{ETHIOPIC SYLLABLE GU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4621 (\N{ETHIOPIC SYLLABLE LE}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
df
# Out:
#                 Channel_name  Subscribers     Views  Total_videos  \
# 0               MERI PODCAST        80100   6645187           161
# 1               Dawit Dreams       491000  52141718           860
# 2                  ወቸው GOOD        101000   8664147            52
# 3              Vintage Media         7030    291614            60
# 4  Gulicha Podcast ጉልቻ ፖድካስት        49100   3102527            66
# 5                   Bunna ቡና        44400   1756418            62
#
#                 Playlist_id
# 0  UUzKNuQ80qNSpt2x-7dsazJg
# 1  UUb3euYUGSY7REtF8NDsMLsA
# 2  UUJD-UtyBgYWqvmp_lknn7Lg
# 3  UUVmDiaSJvb6VH3zPmjVkzfw
# 4  UUCBEcsxu4_i5jdzl4A6xg1w
# 5  UUfiYL9vDNUbq4-zlerxOayw

# %% [markdown]
# ## Function to get video ids

# %%
Playlist_id=df.loc[df['Channel_name']=='Dawit Dreams', 'Playlist_id'].iloc[0]

# %%
Playlist_id
# Out:
# 'UUb3euYUGSY7REtF8NDsMLsA'

# %%
def get_video_ids(youtube,Playlist_id):
    request=youtube.playlistItems().list(
        part='contentDetails',
        playlistId=playlist_id)
    response = request.execute()
    return response

# %%
playlist_id=df.loc[df['Channel_name']=='Dawit Dreams', 'Playlist_id'].iloc[0]

# %%
playlist_id
# Out:
# 'UUb3euYUGSY7REtF8NDsMLsA'

# %%
def get_video_ids(youtube, playlist_id):
    request = youtube.playlistItems().list(
        part='contentDetails',
        playlistId=playlist_id,
        maxResults=50
    )
    response = request.execute()
    video_ids = []
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
    next_page_token = response.get('nextPageToken')
    more_pages = True

    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId=playlist_id,
                maxResults=50,
                pageToken=next_page_token
            )
            response = request.execute()
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            next_page_token = response.get('nextPageToken')
    return video_ids

# %%
video_ids= get_video_ids(youtube,Playlist_id)

# %%
video_ids
# Out:
# ['wztkrl0xsYk',
#  'SxikWJf9tdU',
#  'SLizZFZwiyY',
#  'klh41ItayIs',
#  'y-c28qCIxvU',
#  'w2BrIIiXQfM',
#  'zxp-GMN64IA',
#  'dj2BY9frkA0',
#  '2omVl6TrffM',
#  '3ZyQCdIKmGc',
#  'xCKxLNsukI4',
#  'W3U3ai_HAHA',
#  'SCI_5IFjCE8',
#  'OtyDaYKP3tY',
#  'zx7gOcoqFgk',
#  'sc0pM-b369I',
#  '_W8hpvgKQDo',
#  'XcNY2aDcIrg',
#  'JSe5PRhkj84',
#  'HsocY8UIDxc',
#  'IKDLYIwqomY',
#  '2MgNHrj1lLI',
#  'xw4iqPrfm20',
#  'v53tEnDOvDw',
#  'T5ZB0xpSd1A',
#  's_hQEFM1X-0',
#  'SSwFthxComc',
#  'RWaW_PIiFkY',
#  'pezrRhJZhxw',
#  'MIYP-gPR50c',
#  'y3-Ayur88mM',
#  'Cow4hw6sRrk',
#  'HzQXC_v4x7g',
#  'Mg0Pn20XjaE',
#  'vdqG5Gjd0a8',
#  'buSbKK48GZA',
#  'kn5SKurbz4w',
#  'NW0pIp47t7Y',
#  'ZJ9cdJghDCQ',
#  's_B4KnPV6vY',
#  'w1LUjg5pQrg',
#  'IEUNqji2s5s',
#  '3eNvTKt34xs',
#  'JNLGV6GWeyM',
#  'ckS1gQkOreI',
#  'YSPORbj0Re0',
#  'm6mcVA8ydOA',
#  'O-MFhlEgQJ8',
#  'xXLbZZrJeDA',
#  'iok8Thkj76Q',
#  'Sc-zmGoIxb0',
#  '1Gcf1njcneM',
#  'aPnUzL3KDEg',
#  'jnKqXFpBT24',
#  'O_8b9LX1ttM',
# ...

# %% [markdown]
# ## Function to get video details

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part='snippet,statistics',
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute()
        for video in response['items']: 
            comment_count = video['statistics'].get('commentCount', 'N/A')
            video_stats = dict(
                Title=video['snippet']['title'],
                published_date=video['snippet']['publishedAt'],
                views=video['statistics']['viewCount'],
                likes=video['statistics']['likeCount'],
                favorite=video['statistics']['favoriteCount'],
                comment=comment_count
            )
            all_video_stats.append(video_stats)    
    return all_video_stats

# %%
video_ids=get_video_ids(youtube,playlist_id)

# %%
video_ids
# Out:
# ['wztkrl0xsYk',
#  'SxikWJf9tdU',
#  'SLizZFZwiyY',
#  'klh41ItayIs',
#  'y-c28qCIxvU',
#  'w2BrIIiXQfM',
#  'zxp-GMN64IA',
#  'dj2BY9frkA0',
#  '2omVl6TrffM',
#  '3ZyQCdIKmGc',
#  'xCKxLNsukI4',
#  'W3U3ai_HAHA',
#  'SCI_5IFjCE8',
#  'OtyDaYKP3tY',
#  'zx7gOcoqFgk',
#  'sc0pM-b369I',
#  '_W8hpvgKQDo',
#  'XcNY2aDcIrg',
#  'JSe5PRhkj84',
#  'HsocY8UIDxc',
#  'IKDLYIwqomY',
#  '2MgNHrj1lLI',
#  'xw4iqPrfm20',
#  'v53tEnDOvDw',
#  'T5ZB0xpSd1A',
#  's_hQEFM1X-0',
#  'SSwFthxComc',
#  'RWaW_PIiFkY',
#  'pezrRhJZhxw',
#  'MIYP-gPR50c',
#  'y3-Ayur88mM',
#  'Cow4hw6sRrk',
#  'HzQXC_v4x7g',
#  'Mg0Pn20XjaE',
#  'vdqG5Gjd0a8',
#  'buSbKK48GZA',
#  'kn5SKurbz4w',
#  'NW0pIp47t7Y',
#  'ZJ9cdJghDCQ',
#  's_B4KnPV6vY',
#  'w1LUjg5pQrg',
#  'IEUNqji2s5s',
#  '3eNvTKt34xs',
#  'JNLGV6GWeyM',
#  'ckS1gQkOreI',
#  'YSPORbj0Re0',
#  'm6mcVA8ydOA',
#  'O-MFhlEgQJ8',
#  'xXLbZZrJeDA',
#  'iok8Thkj76Q',
#  'Sc-zmGoIxb0',
#  '1Gcf1njcneM',
#  'aPnUzL3KDEg',
#  'jnKqXFpBT24',
#  'O_8b9LX1ttM',
# ...

# %%
video_details=get_video_details(youtube,video_ids)

# %%
video_data=pd.DataFrame(video_details)

# %%
import pandas as pd
video_data['published_date'] = pd.to_datetime(video_data['published_date']).dt.date
for col in ['views', 'likes']:
    video_data[col] = pd.to_numeric(video_data[col], errors='coerce')

# %%
   video_data['views']=pd.to_numeric(video_data['views'])
video_data['likes']=pd.to_numeric(video_data['likes'])

# %%
top10_videos=video_data.sort_values(by='views' , ascending=False).head(10)

# %%
top10_videos
# Out:
#                                                  Title published_date  \
# 513  ከጋራዥ ተነስቶ የሚዲያ ተቋም እስከ መምራት | ኮሜዲያን እሸቱ መለሰ  @...     2022-08-14
# 273  ጫማ ሚወለቅበት ቤት ስጠላ ፓስተር ቸሬ @dawitdreams @Epaphra...     2023-05-28
# 545  የእኔ እዚህ መድረስ ምክነያቱ አባቴ ነው? ተዓምረኛዋ ዳጊ ሾው @dawit...     2022-07-19
# 633  የኤርሚያስ አመልጋ የጥንካሬው ምስጢር @Dawit Dreams #dawitdr...     2022-01-24
# 415  ሊሞቱ 3 ወር የቀራቸዉ ሰዎች ባለማድረጋቸው የሚቆጫቸው 10 ነገሮች ዶ/ር...     2022-12-18
# 472  የቱ መቅደም አለበት ገንዘብ ወይስ እውቀት? ሊዲያና ሰሎሞን @DawitDr...     2022-10-09
# 315  በጉርምስና የሚመጣ ለውጥ ጥንቃቄ ካልተደረገበት በሽምግልና የኔቢጤ ያደርጋ...     2023-04-23
# 599  " እንዴት ወደ ከፍታው መጓዝ እና እዚያው መቆየት እንችላለን "  ዶ/ር ...     2022-04-11
# 424  እምነት ምንድን ነው? DAWIT DREAMS SEMINAR 4 (አራት)  @D...     2022-12-08
# 621  " ትዳር ዘው ተብሎ አይገባም ትኩስ እፉ ነው " ፓስተር ቸሬ @Dawit ...     2022-02-09
#
#        views  likes favorite  comment
# 513  1722076  30023        0   1202.0
# 273  1220646  13052        0   1379.0
# 545  1100069  21803        0   1147.0
# 633   941655  14912        0   1111.0
# ...

# %%
ax1=sns.barplot(x='views', y='Title',data=top10_videos)
# Out:
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4776 (\N{ETHIOPIC SYLLABLE KA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4875 (\N{ETHIOPIC SYLLABLE GAA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4651 (\N{ETHIOPIC SYLLABLE RAA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4837 (\N{ETHIOPIC SYLLABLE ZHE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\envs\YTA-analysis-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 4720 (\N{ETHIOPIC SYLLABLE TA}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
video_data['Month']=pd.to_datetime(video_data['published_date']).dt.strftime('%b')

# %%
video_data
# Out:
#                                                  Title published_date   views  \
# 0    የህልም ዋና አላማ ከገባህ መቼም አትከስርም @dawitdreams|  #et...     2024-04-30     912
# 1    አንድ ቢትኮይን 72ሺ ዶላር ሸጫለሁ...  @dawitdreams  | Men...     2024-04-28  102663
# 2    መንሱር ጀማል በዳዊት ድሪምስ የ21ኛው ክፍለ ዘመን ጀግና @DawitDre...     2024-04-27   17137
# 3              ህልምህን ለማሳካት ምን ያህል ዝግጁ ነህ? @DawitDreams     2024-04-26   12871
# 4    ከሰባት በላይ የተለያዩ ስራዎችን እሰራለው |@DawitDreams | Eth...     2024-04-24   28489
# ..                                                 ...            ...     ...
# 855               Dreams Success Seminar 2018 Ethiopia     2017-12-17   15169
# 856                           Dreams: Change your Life     2017-10-04    5662
# 857                              Toastmasters   SYTYCS     2014-07-26    4214
# 858              Ethiopian Motivation: I am Phenomenal     2014-07-22   12980
# 859           Dreams Motivation 2014 : You are Amazing     2014-01-17   16337
#
# ...

# %%
video_per_month=video_data.groupby('Month',as_index=False).size()

# %%
video_per_month
# Out:
#    Month  size
# 0    Apr    72
# 1    Aug    83
# 2    Dec    78
# 3    Feb    70
# 4    Jan    73
# 5    Jul    65
# 6    Jun    61
# 7    Mar    65
# 8    May    73
# 9    Nov    63
# 10   Oct    84
# 11   Sep    73

# %%
import pandas as pd

# %%
videos_per_month = pd.DataFrame({
    'Month': ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'],
    'VideoCount': [10, 15, 8, 12, 6, 11, 14, 7, 9, 16, 13, 17]
})

# %%
sort_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'], categories=sort_order, ordered=True)

# %%
videos_per_month = videos_per_month.sort_index()

# %%
videos_per_month
# Out:
#                Month  VideoCount
# Month
# January      January          10
# February    February          15
# March          March           8
# April          April          12
# May              May           6
# June            June          11
# July            July          14
# August        August           7
# September  September           9
# October      October          16
# November    November          13
# December    December          17

# %%
ax2=sns.barplot(x='Month',y='VideoCount',data=videos_per_month)

# %%
video_data
# Out:
#                                                  Title published_date   views  \
# 0    የህልም ዋና አላማ ከገባህ መቼም አትከስርም @dawitdreams|  #et...     2024-04-30     912
# 1    አንድ ቢትኮይን 72ሺ ዶላር ሸጫለሁ...  @dawitdreams  | Men...     2024-04-28  102663
# 2    መንሱር ጀማል በዳዊት ድሪምስ የ21ኛው ክፍለ ዘመን ጀግና @DawitDre...     2024-04-27   17137
# 3              ህልምህን ለማሳካት ምን ያህል ዝግጁ ነህ? @DawitDreams     2024-04-26   12871
# 4    ከሰባት በላይ የተለያዩ ስራዎችን እሰራለው |@DawitDreams | Eth...     2024-04-24   28489
# ..                                                 ...            ...     ...
# 855               Dreams Success Seminar 2018 Ethiopia     2017-12-17   15169
# 856                           Dreams: Change your Life     2017-10-04    5662
# 857                              Toastmasters   SYTYCS     2014-07-26    4214
# 858              Ethiopian Motivation: I am Phenomenal     2014-07-22   12980
# 859           Dreams Motivation 2014 : You are Amazing     2014-01-17   16337
#
# ...

# %%
video_data.to_csv('Detail_video(Dawit Dreams)')
